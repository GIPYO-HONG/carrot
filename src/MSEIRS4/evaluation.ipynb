# %%
import jax.numpy as jnp
import numpy as np
import jax.nn as jnn

import equinox as eqx

from models import *

# %%
from exp import exp as ex

# %%
model = ex.model
EX = ex.EX
steps = ex.steps

ts_eval = ex.ts_eval

exp_name = ex.exp_name
path = f"results/{exp_name}"
param_path = f"{path}/model_parameter/model_step_{steps:05d}.eqx"
loss_list = np.load(f"{path}/loss_list.npy")

EX.model = eqx.tree_deserialise_leaves(
    param_path,
    EX.model
)

# %%
model.Evaluation(EX, ts_eval, loss_list, viz_data=False)

# %%
jnn.softmax(EX.model.y0)
# Out:
# Array([0.00267527, 0.06934825, 0.02441616, 0.01364168, 0.0082515 ,
#        0.10446494, 0.00441618, 0.00285261, 0.00293832, 0.03986829,
#        0.04371503, 0.02970806, 0.01101052, 0.22228912, 0.06574289,
#        0.05539829, 0.29926288], dtype=float32)
