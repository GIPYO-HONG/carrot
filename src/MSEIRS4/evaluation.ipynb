# %%
import jax.numpy as jnp
import numpy as np
import jax.nn as jnn

import equinox as eqx

from models import *

# %%
from exp import exp2 as ex

# %%
model = ex.model
EX = ex.EX
# steps = ex.steps
steps = 13000

ts_eval = ex.ts_eval

exp_name = ex.exp_name
path = f"results/{exp_name}"
param_path = f"{path}/model_parameter/model_step_{steps:05d}.eqx"
loss_list = np.load(f"{path}/loss_list.npy")

EX.model = eqx.tree_deserialise_leaves(
    param_path,
    EX.model
)

# %%
model.Evaluation(EX, ts_eval, loss_list, viz_data=False)

# %%
jnn.softmax(EX.model.y0)
# Out:
# Array([4.6087813e-04, 4.5353277e-03, 8.0610713e-04, 1.1044689e-03,
#        1.1434214e-03, 1.5938170e-02, 2.4658598e-03, 3.3152609e-03,
#        3.4932946e-03, 4.8526175e-02, 8.2983505e-03, 1.1704869e-02,
#        4.2573329e-02, 5.7188851e-01, 9.4453348e-03, 1.4734375e-02,
#        2.5956625e-01], dtype=float32)
