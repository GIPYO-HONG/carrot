# %%
import jax.numpy as jnp
import numpy as np

import equinox as eqx

from models import *

# %%
from exp import ex12 as ex
# Out:
# /root/workspace/carrot/src/models/NODE_1.py:113: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   model = NODE(

# %%
model = ex.model
EX = ex.EX
steps = ex.steps

beta = ex.beta
y0 = ex.y0
ts = ex.ts
ys = ex.ys

ts_eval = ex.ts_eval

exp_name = ex.exp_name
path = f"results/{exp_name}"
param_path = f"{path}/model_parameter/model_step_{steps:05d}.eqx"
loss_list = np.load(f"{path}/loss_list.npy")

EX.model = eqx.tree_deserialise_leaves(
    param_path,
    EX.model
)

# %%
model.Evaluation(EX, ts_eval, loss_list, viz_data=False)
